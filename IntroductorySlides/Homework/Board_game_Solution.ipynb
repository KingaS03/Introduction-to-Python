# %%
import numpy as np

# %%
class Dice:
    _MAX_N_SIDES=10
    
    def __init__(self, num_sides=6):
        if num_sides > Dice._MAX_N_SIDES:
            raise ValueError('number of sides can\'t be bigger than %d. Given %d' % (Dice._MAX_N_SIDES,
                                                                                    num_sides))        
        self.n = num_sides
        
    def roll(self):
        return np.random.choice(self.n)+1
    
    @staticmethod
    def get_max_sides():
        return Dice._MAX_N_SIDES
    
def dice_roll(d):
    return np.random.choice(d.n)+1

# %%
class Board:
    def __init__(self, num_fields=100,
                 snakes={40:10,
                         45:30,
                         61:21,
                         83:72,
                         92:7,
                         96:74},
                 ladders={3:34,
                         10:24,
                         26:66,
                         47:79,
                         69:99},
                 num_players=2
                ):
        if num_fields <= 1:
            raise ValueError('Number of fields should be bigger than 1. Now it is %d' % (num_fields))
            
        self.num_fields = num_fields
        self.snakes = snakes.copy()
        self.ladders = ladders.copy()
        
        if 0 in ladders.keys():
            raise ValueError('Can\'t have ladder from first position')
            
        if self.num_fields in self.snakes.keys():
            raise ValueError('Can\'t have snake head in end position')
            
        if np.max(list(self.snakes.values())) >= self.num_fields or np.min(list(self.snakes.values())) <0:
            raise ValueError('Snake tail cannot be outside of the board')
            
        if np.max(list(self.ladders.values())) >= self.num_fields or np.min(list(self.ladders.values())) <0:
            raise ValueError('Ladder end cannot be outside of the board')
            
        self.num_players = num_players
        self.pos = [0] * self.num_players
        
        self.curr_player = 0
            
    def set_current_player(self, player_idx):
        if len(self.pos)<=player_idx:
            raise ValueError('Wrong player index')
        self.curr_player = player_idx
        
    def make_move(self, num_fields):
        self.pos[self.curr_player] = min(self.num_fields-1,
                                         self.pos[self.curr_player] + num_fields)
        
    def player_won(self):
        return self.pos[self.curr_player] == (self.num_fields - 1)
    
    def at_snake_head(self):
        return self.pos[self.curr_player] in self.snakes
    
    def move_to_snake_tail(self):
        if not self.at_snake_head():
            raise RuntimeError('Impossible move requested: not at a snake head position')
            
        target_pos = self.snakes[self.pos[self.curr_player]]
        self.pos[self.curr_player] = target_pos
            
    def at_ladder_start(self):
        return self.pos[self.curr_player] in self.ladders
    
    def move_to_ladder_end(self):
        if not self.at_ladder_start():
            raise RuntimeError('Impossible move requested: not at a ladder start position')

        target_pos = self.ladders[self.pos[self.curr_player]]
        self.pos[self.curr_player] = target_pos
    
    def get_position(self):
        return self.pos[self.curr_player]
    
    def reset(self):
        self.pos = [0] * self.num_players
        
    def print_player_positions(self):
        print('\n___________\nPlayer positions:')
        for i, pos in enumerate(self.pos):
            print('%d\t%d' % (i+1, pos+1))

# %% [markdown]
# # Solution

# %%
num_players = 10

b = Board(num_players=num_players)
d = Dice()

# %%
curr_player = 0
b.reset()
b.set_current_player(curr_player)

while True:
    steps = d.roll()
    
    print('player %d makes %d steps' % (curr_player+1, steps))
    b.make_move(steps)
    
    if b.at_ladder_start():
        p1 = b.get_position()
        b.move_to_ladder_end()
        p2 = b.get_position()
        print('player %d took ladder %d -> %d' % (curr_player+1, p1, p2))

    if b.at_snake_head():
        p1 = b.get_position()
        b.move_to_snake_tail()
        p2 = b.get_position()
        print('player %d was eaten by a snake %d -> %d' % (curr_player+1, p1, p2))
        
    if b.player_won():
        print('player %d WON!!!!!!'% (curr_player+1))
        b.print_player_positions()
        break
        
    curr_player += 1
    curr_player = curr_player % num_players
    b.set_current_player(curr_player)
# Out:
# player 1 makes 1 steps
# player 2 makes 1 steps
# player 3 makes 3 steps
# player 3 took ladder 3 -> 34
# player 4 makes 1 steps
# player 5 makes 4 steps
# player 6 makes 3 steps
# player 6 took ladder 3 -> 34
# player 7 makes 1 steps
# player 8 makes 1 steps
# player 9 makes 1 steps
# player 10 makes 6 steps
# player 1 makes 2 steps
# player 1 took ladder 3 -> 34
# player 2 makes 3 steps
# player 3 makes 2 steps
# player 4 makes 6 steps
# player 5 makes 2 steps
# player 6 makes 4 steps
# player 7 makes 1 steps
# player 8 makes 2 steps
# player 8 took ladder 3 -> 34
# player 9 makes 2 steps
# player 9 took ladder 3 -> 34
# player 10 makes 3 steps
# player 1 makes 1 steps
# player 2 makes 5 steps
# player 3 makes 5 steps
# player 4 makes 1 steps
# player 5 makes 4 steps
# player 5 took ladder 10 -> 24
# player 6 makes 3 steps
# player 7 makes 2 steps
# player 8 makes 4 steps
# player 9 makes 1 steps
# player 10 makes 1 steps
# player 10 took ladder 10 -> 24
# player 1 makes 1 steps
# player 2 makes 3 steps
# player 3 makes 5 steps
# player 4 makes 4 steps
# player 5 makes 4 steps
# player 6 makes 5 steps
# player 7 makes 1 steps
# player 8 makes 5 steps
# player 9 makes 4 steps
# player 10 makes 2 steps
# player 10 took ladder 26 -> 66
# player 1 makes 1 steps
# player 2 makes 4 steps
# player 3 makes 5 steps
# player 4 makes 2 steps
# player 5 makes 3 steps
# player 6 makes 4 steps
# player 7 makes 2 steps
# player 8 makes 2 steps
# player 8 was eaten by a snake 45 -> 30
# player 9 makes 4 steps
# player 10 makes 2 steps
# player 1 makes 2 steps
# player 2 makes 1 steps
# player 3 makes 4 steps
# player 4 makes 2 steps
# player 5 makes 5 steps
# player 6 makes 5 steps
# player 7 makes 4 steps
# player 8 makes 1 steps
# player 9 makes 3 steps
# player 10 makes 4 steps
# player 1 makes 2 steps
# player 2 makes 6 steps
# player 3 makes 6 steps
# player 3 was eaten by a snake 61 -> 21
# player 4 makes 6 steps
# player 5 makes 5 steps
# player 6 makes 1 steps
# player 7 makes 3 steps
# player 8 makes 5 steps
# player 9 makes 6 steps
# player 10 makes 1 steps
# player 1 makes 2 steps
# player 2 makes 1 steps
# player 3 makes 6 steps
# player 4 makes 2 steps
# player 5 makes 3 steps
# player 6 makes 5 steps
# player 6 was eaten by a snake 61 -> 21
# player 7 makes 1 steps
# player 8 makes 1 steps
# player 9 makes 2 steps
# player 10 makes 1 steps
# player 1 makes 5 steps
# player 2 makes 1 steps
# player 3 makes 2 steps
# player 4 makes 2 steps
# player 4 took ladder 26 -> 66
# player 5 makes 4 steps
# player 6 makes 2 steps
# player 7 makes 1 steps
# player 8 makes 4 steps
# player 9 makes 6 steps
# player 10 makes 3 steps
# player 1 makes 2 steps
# player 2 makes 1 steps
# player 2 took ladder 26 -> 66
# player 3 makes 6 steps
# player 4 makes 1 steps
# player 5 makes 2 steps
# player 6 makes 5 steps
# player 7 makes 4 steps
# player 8 makes 2 steps
# player 9 makes 1 steps
# player 9 was eaten by a snake 61 -> 21
# player 10 makes 1 steps
# player 1 makes 2 steps
# player 2 makes 1 steps
# player 3 makes 5 steps
# player 3 was eaten by a snake 40 -> 10
# player 4 makes 3 steps
# player 5 makes 4 steps
# player 6 makes 2 steps
# player 7 makes 5 steps
# player 8 makes 2 steps
# player 8 was eaten by a snake 45 -> 30
# player 9 makes 6 steps
# player 10 makes 2 steps
# player 1 makes 3 steps
# player 2 makes 5 steps
# player 3 makes 1 steps
# player 4 makes 3 steps
# player 5 makes 2 steps
# player 6 makes 6 steps
# player 7 makes 5 steps
# player 8 makes 4 steps
# player 9 makes 4 steps
# player 10 makes 2 steps
# player 1 makes 5 steps
# player 2 makes 5 steps
# player 3 makes 1 steps
# player 4 makes 2 steps
# player 5 makes 1 steps
# player 6 makes 3 steps
# player 7 makes 6 steps
# player 8 makes 4 steps
# player 9 makes 2 steps
# player 10 makes 4 steps
# player 1 makes 6 steps
# player 2 makes 1 steps
# player 3 makes 1 steps
# player 4 makes 6 steps
# player 5 makes 3 steps
# player 6 makes 1 steps
# player 6 was eaten by a snake 40 -> 10
# player 7 makes 2 steps
# player 8 makes 5 steps
# player 9 makes 2 steps
# player 10 makes 4 steps
# player 1 makes 4 steps
# player 2 makes 2 steps
# player 3 makes 2 steps
# player 4 makes 5 steps
# player 5 makes 5 steps
# player 6 makes 4 steps
# player 7 makes 3 steps
# player 8 makes 2 steps
# player 8 was eaten by a snake 45 -> 30
# player 9 makes 3 steps
# player 10 makes 2 steps
# player 10 was eaten by a snake 92 -> 7
# player 1 makes 6 steps
# player 2 makes 3 steps
# player 2 was eaten by a snake 83 -> 72
# player 3 makes 4 steps
# player 4 makes 3 steps
# player 5 makes 4 steps
# player 5 took ladder 69 -> 99
# player 5 WON!!!!!!
#
# ___________
# Player positions:
# 1	77
# 2	73
# 3	20
# 4	90
# 5	100
# 6	15
# 7	42
# 8	31
# 9	39
# 10	8
